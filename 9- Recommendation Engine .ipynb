# %% [markdown]
# ##  Building a recommender system by using cosine similarties score for the books data

# %%
import pandas as pd
import numpy as np

# %%
book = pd.read_excel('book.xls')

# %% [markdown]
# ### Renaming to understand the index values better

# %%
book1= book.rename({'Unnamed: 0': 'userid', 'User.ID': 'ID', 'Book.Title': 'Title', 'Book.Rating': 'Rating'}, axis = 1)
book1
# Out:
#       userid      ID                                              Title  \
# 0          1  276726                                Classical Mythology
# 1          2  276729                                       Clara Callan
# 2          3  276729                               Decision in Normandy
# 3          4  276736  Flu: The Story of the Great Influenza Pandemic...
# 4          5  276737                             The Mummies of Urumchi
# ...      ...     ...                                                ...
# 9995    9996  162121       American Fried: Adventures of a Happy Eater.
# 9996    9997  162121                              Cannibal In Manhattan
# 9997    9998  162121                    How to Flirt: A Practical Guide
# 9998    9999  162121                                           Twilight
# 9999   10000  162129                       Kids Say the Darndest Things
#
#       Rating
# 0          5
# 1          3
# 2          6
# 3          8
# 4          6
# ...      ...
# 9995       7
# 9996       9
# 9997       7
# 9998       8
# 9999       6
#
# [10000 rows x 4 columns]

# %%
book1.sort_values('userid')
# Out:
#       userid      ID                                              Title  \
# 0          1  276726                                Classical Mythology
# 1          2  276729                                       Clara Callan
# 2          3  276729                               Decision in Normandy
# 3          4  276736  Flu: The Story of the Great Influenza Pandemic...
# 4          5  276737                             The Mummies of Urumchi
# ...      ...     ...                                                ...
# 9995    9996  162121       American Fried: Adventures of a Happy Eater.
# 9996    9997  162121                              Cannibal In Manhattan
# 9997    9998  162121                    How to Flirt: A Practical Guide
# 9998    9999  162121                                           Twilight
# 9999   10000  162129                       Kids Say the Darndest Things
#
#       Rating
# 0          5
# 1          3
# 2          6
# 3          8
# 4          6
# ...      ...
# 9995       7
# 9996       9
# 9997       7
# 9998       8
# 9999       6
#
# [10000 rows x 4 columns]

# %%
book1.sort_values('userid')
# Out:
#       userid      ID                                              Title  \
# 0          1  276726                                Classical Mythology
# 1          2  276729                                       Clara Callan
# 2          3  276729                               Decision in Normandy
# 3          4  276736  Flu: The Story of the Great Influenza Pandemic...
# 4          5  276737                             The Mummies of Urumchi
# ...      ...     ...                                                ...
# 9995    9996  162121       American Fried: Adventures of a Happy Eater.
# 9996    9997  162121                              Cannibal In Manhattan
# 9997    9998  162121                    How to Flirt: A Practical Guide
# 9998    9999  162121                                           Twilight
# 9999   10000  162129                       Kids Say the Darndest Things
#
#       Rating
# 0          5
# 1          3
# 2          6
# 3          8
# 4          6
# ...      ...
# 9995       7
# 9996       9
# 9997       7
# 9998       8
# 9999       6
#
# [10000 rows x 4 columns]

# %%
len(book1.userid.unique())
# Out:
# 10000

# %%
len(book1.ID.unique())
# Out:
# 2182

# %%
book1['Rating'].value_counts().sort_index()
#we can see the rating values for different titles across the data
# Out:
# 1       43
# 2       63
# 3      146
# 4      237
# 5     1007
# 6      920
# 7     2076
# 8     2283
# 9     1493
# 10    1732
# Name: Rating, dtype: int64

# %%
book1['Title'].value_counts()
#the total rating the different titles have received
# Out:
# Fahrenheit 451                                              5
# Charlie and the Chocolate Factory                           4
# The Subtle Knife (His Dark Materials, Book 2)               4
# Vanished                                                    4
# Ender's Game (Ender Wiggins Saga (Paperback))               4
#                                                            ..
# Murder on St. Mark's Place (Gaslight Mysteries)             1
# State of Grace                                              1
# Valsalva's Maneuver: Mots Justes and Indispensable Terms    1
# I love you, I hate you                                      1
# Kids Say the Darndest Things                                1
# Name: Title, Length: 9659, dtype: int64

# %%
book1_df= book1.pivot(index='userid', columns='Title', values='Rating')
book1_df
# this will give us the relationship between various users as per their likelihood of liking a title or not
# Out:
# Title   Classical Mythology  Clara Callan  Decision in Normandy  \
# userid
# 1                       5.0           NaN                   NaN
# 2                       NaN           3.0                   NaN
# 3                       NaN           NaN                   6.0
# 4                       NaN           NaN                   NaN
# 5                       NaN           NaN                   NaN
# ...                     ...           ...                   ...
# 9996                    NaN           NaN                   NaN
# 9997                    NaN           NaN                   NaN
# 9998                    NaN           NaN                   NaN
# 9999                    NaN           NaN                   NaN
# 10000                   NaN           NaN                   NaN
#
# Title   Flu: The Story of the Great Influenza Pandemic of 1918 and the Search for the Virus That Caused It  \
# userid
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     8.0
# 5                                                     NaN
# ...                                                   ...
# 9996                                                  NaN
# 9997                                                  NaN
# 9998                                                  NaN
# 9999                                                  NaN
# 10000                                                 NaN
#
# Title   The Mummies of Urumchi  The Kitchen God's Wife  \
# userid
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# 5                          6.0                     NaN
# ...                        ...                     ...
# 9996                       NaN                     NaN
# 9997                       NaN                     NaN
# 9998                       NaN                     NaN
# 9999                       NaN                     NaN
# 10000                      NaN                     NaN
#
# Title   What If?: The World's Foremost Military Historians Imagine What Might Have Been  \
# userid
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 9996                                                  NaN
# 9997                                                  NaN
# 9998                                                  NaN
# 9999                                                  NaN
# 10000                                                 NaN
#
# Title   PLEADING GUILTY  \
# userid
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# ...                 ...
# 9996                NaN
# 9997                NaN
# 9998                NaN
# 9999                NaN
# 10000               NaN
#
# Title   Under the Black Flag: The Romance and the Reality of Life Among the Pirates  \
# userid
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 9996                                                  NaN
# 9997                                                  NaN
# 9998                                                  NaN
# 9999                                                  NaN
# 10000                                                 NaN
#
# Title   Where You'll Find Me: And Other Stories  ...  The Cloister Walk  \
# userid                                           ...
# 1                                           NaN  ...                NaN
# 2                                           NaN  ...                NaN
# 3                                           NaN  ...                NaN
# 4                                           NaN  ...                NaN
# 5                                           NaN  ...                NaN
# ...                                         ...  ...                ...
# 9996                                        NaN  ...                NaN
# 9997                                        NaN  ...                NaN
# 9998                                        NaN  ...                NaN
# 9999                                        NaN  ...                NaN
# 10000                                       NaN  ...                NaN
#
# Title   Open Water  The Evolution of Jane  AT PARADISE GATE  \
# userid
# 1              NaN                    NaN               NaN
# 2              NaN                    NaN               NaN
# 3              NaN                    NaN               NaN
# 4              NaN                    NaN               NaN
# 5              NaN                    NaN               NaN
# ...            ...                    ...               ...
# 9996           NaN                    NaN               NaN
# 9997           NaN                    NaN               NaN
# 9998           NaN                    NaN               NaN
# 9999           NaN                    NaN               NaN
# 10000          NaN                    NaN               NaN
#
# Title   I Should Have Stayed Home: The Worst Trips of the Great Writers (Travel Literature Series)  \
# userid
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 9996                                                  NaN
# 9997                                                  NaN
# 9998                                                  NaN
# 9999                                                  NaN
# 10000                                                 NaN
#
# Title   American Fried: Adventures of a Happy Eater.  Cannibal In Manhattan  \
# userid
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
# 5                                                NaN                    NaN
# ...                                              ...                    ...
# 9996                                             7.0                    NaN
# 9997                                             NaN                    9.0
# 9998                                             NaN                    NaN
# 9999                                             NaN                    NaN
# 10000                                            NaN                    NaN
#
# Title   How to Flirt: A Practical Guide  Twilight  \
# userid
# 1                                   NaN       NaN
# 2                                   NaN       NaN
# 3                                   NaN       NaN
# 4                                   NaN       NaN
# 5                                   NaN       NaN
# ...                                 ...       ...
# 9996                                NaN       NaN
# 9997                                NaN       NaN
# 9998                                7.0       NaN
# 9999                                NaN       8.0
# 10000                               NaN       NaN
#
# Title   Kids Say the Darndest Things
# userid
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# ...                              ...
# 9996                             NaN
# 9997                             NaN
# 9998                             NaN
# 9999                             NaN
# 10000                            6.0
#
# [10000 rows x 9659 columns]

# %%
book1_df.fillna(0, inplace=True)
book1_df
# checking the similarity between various users, their rating for different titles and replacing nan with 0

# %%
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine, correlation

# %%
user_sim = 1-pairwise_distances(book1_df.values, metric='cosine')
user_sim

# %%
user_sim_df = pd.DataFrame(user_sim)
user_sim_df

# %%
user_sim_df.index = book1.userid.unique()
user_sim_df.columns = book1.userid.unique()
user_sim_df.iloc[0:10, 0:10]

# %%
np.fill_diagonal(user_sim, 0)
user_sim_df.idxmax(axis=1)[0:10]
#we can see. ost similar users

# %%
book1[(book1['userid']==6) | (book1['userid']==1) | (book1['userid']==10)| (book1['userid']==4)]

# %%
# there is not much similarity between various users and hence we cannot conclude much.
# however, we can surely say that various users are similar to userid 6 and can recommend a few titles basis the ratings by common users
